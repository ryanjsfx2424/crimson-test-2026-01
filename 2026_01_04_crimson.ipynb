# %%
print("hello world")
# Out:
# hello world

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img=mpimg.imread('qso2237_wiyn_1024.jpg')

# %%
img.shape
# Out:
# (680, 1024, 3)

# %%
red = img[:,:,0]
green = img[:,:,1]
blue = img[:,:,2]

# %%
plt.plot(red, green, ".")
plt.plot(np.arange(0, 255, 255), np.arange(0, 255, 255), label="line")
plt.xlabel("red")
plt.ylabel("green")
plt.legend()
plt.show()

# %%
np.savez_compressed("/content/drive/MyDrive/2026/red_data_apod.npz", red=red)

# %%
with np.load("/content/drive/MyDrive/2026/red_data_apod.npz") as data:
  red = data["red"]
